# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#bse
intro = "The best time to do a breast self-exam is a few days after your monthly menstrual cycle ends. Hormonal changes can affect the size and feel of your breasts, so it’s best to perform the exam when your breasts are in their normal state.Women who don’t menstruate should choose a certain day to perform the exam, such as the first day of each month.You should also keep a journal of your self-exams. This will help you track and record any changes you have noticed in your breasts."
def intro_bse():
    return (intro)
def intro_img():
    #intro_bse()
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('/content/drive/MyDrive/breast_cancer/bse/intro.png')
    plt.imshow(img)
    plt.axis('off')
    plt.show()
user_response = "hi"
intro_bse()
#intro_img()
# Out:
# 'The best time to do a breast self-exam is a few days after your monthly menstrual cycle ends. Hormonal changes can affect the size and feel of your breasts, so it’s best to perform the exam when your breasts are in their normal state.Women who don’t menstruate should choose a certain day to perform the exam, such as the first day of each month.You should also keep a journal of your self-exams. This will help you track and record any changes you have noticed in your breasts.'

# %%
def intro_img():
    #intro_bse()
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('/content/drive/MyDrive/breast_cancer/bse/intro.png')
    plt.imshow(img)
    plt.axis('off')
    plt.show()
intro_img()

# %%
#step1 img
def step1_img():
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('/content/drive/MyDrive/breast_cancer/bse/1st.jpeg')
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
#step2 img 
def step2_img():
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('/content/drive/MyDrive/breast_cancer/bse/2nd.jpeg')
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
#step3_img
def step3_img():
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('/content/drive/MyDrive/breast_cancer/bse/3rd.jpeg')
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
#bse2
def bse_1():
    step1_img()
    step2_img()
    step3_img()
    step_01 = "Start by standing topless in front of a mirror with your hands at your sides.Visually inspect your breasts for the following:"
    step_02 = " changes in size, shape, or symmetry dimpling inverted nipples puckering asymmetrical ridges at the bottom"
    return (step_01 + step_02)

# %%
bse_1()
# Out:
# 'Start by standing topless in front of a mirror with your hands at your sides.Visually inspect your breasts for the following: changes in size, shape, or symmetry dimpling inverted nipples puckering asymmetrical ridges at the bottom'

# %%
#step4 img
def step4_img():
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('/content/drive/MyDrive/breast_cancer/bse/4th.jpeg')
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
#bse 2
def bse_2():
    step4_img()
    step4 = "With tips of the fingers together, feel your breast up and downwards.Also in round movements, starting from the outer part and pull inwards to the nipple"
    return step4
bse_2()
# Out:
# 'With tips of the fingers together, feel your breast up and downwards.Also in round movements, starting from the outer part and pull inwards to the nipple'

# %%
#step 5 img
def step5_img():
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('/content/drive/MyDrive/breast_cancer/bse/5th.jpeg')
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
def bse_3():
    step5_img()
    step5 = "Lying on a cushion repeat all the previous movements"
    return step5 
bse_3()
# Out:
# 'Lying on a cushion repeat all the previous movements'

# %%
#step6 img
def step6_img():
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('/content/drive/MyDrive/breast_cancer/bse/6th.jpeg')
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
#bse4
def bse_4():
    step6_img()
    step6 = "Place your thumb and forefinger on the tissue around the nipple and press.Look for any abnormal discharge"
    return step6
bse_4()
# Out:
# 'Place your thumb and forefinger on the tissue around the nipple and press.Look for any abnormal discharge'
